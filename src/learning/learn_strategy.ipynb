# %% [markdown]
# The strategy
# Market: S&P 500
# Entry (buy on next days open):
# 1. S&P Price above 200-d Moving Average
# 2. 10-period RSI below 30
# Exit (sell on next days open):
# 10-period RSI above 40 or after 10 trading days

# %%
# %timeit
import pandas as pd
import yfinance as yf
import ta
import numpy as np

df=yf.download( '^GSPC', start='1996-01-01')
df.describe
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <bound method NDFrame.describe of                    Open         High          Low        Close    Adj Close  \
# Date
# 1996-01-02   615.929993   620.739990   613.169983   620.729980   620.729980
# 1996-01-03   620.729980   623.250000   619.559998   621.320007   621.320007
# 1996-01-04   621.320007   624.489990   613.960022   617.700012   617.700012
# 1996-01-05   617.700012   617.700012   612.020020   616.710022   616.710022
# 1996-01-08   616.710022   618.460022   616.489990   618.460022   618.460022
# ...                 ...          ...          ...          ...          ...
# 2024-07-29  5476.549805  5487.740234  5444.439941  5463.540039  5463.540039
# 2024-07-30  5478.729980  5489.459961  5401.700195  5436.439941  5436.439941
# 2024-07-31  5505.589844  5551.509766  5493.750000  5522.299805  5522.299805
# 2024-08-01  5537.839844  5566.160156  5410.419922  5446.680176  5446.680176
# 2024-08-02  5376.629883  5383.890137  5302.029785  5346.560059  5346.560059
#
#                 Volume
# Date
# 1996-01-02   364180000
# 1996-01-03   468950000
# 1996-01-04   512580000
# 1996-01-05   437110000
# 1996-01-08   130360000
# ...                ...
# 2024-07-29  3379970000
# 2024-07-30  3777740000
# 2024-07-31  4546910000
# 2024-08-01  4703620000
# 2024-08-02  5156450000
#
# [7196 rows x 6 columns]>

# %%
df['sma200'] = ta.trend.sma_indicator(df.Close, window=200)

df['rsi'] = ta.momentum.rsi(df.Close,window=10)

# %%
df['signal'] = np.where((df.Close > df.sma200) & (df.rsi < 30), True, False)

# %%
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1996-01-02   615.929993   620.739990   613.169983   620.729980   620.729980
# 1996-01-03   620.729980   623.250000   619.559998   621.320007   621.320007
# 1996-01-04   621.320007   624.489990   613.960022   617.700012   617.700012
# 1996-01-05   617.700012   617.700012   612.020020   616.710022   616.710022
# 1996-01-08   616.710022   618.460022   616.489990   618.460022   618.460022
# ...                 ...          ...          ...          ...          ...
# 2024-07-29  5476.549805  5487.740234  5444.439941  5463.540039  5463.540039
# 2024-07-30  5478.729980  5489.459961  5401.700195  5436.439941  5436.439941
# 2024-07-31  5505.589844  5551.509766  5493.750000  5522.299805  5522.299805
# 2024-08-01  5537.839844  5566.160156  5410.419922  5446.680176  5446.680176
# 2024-08-02  5376.629883  5383.890137  5302.029785  5346.560059  5346.560059
#
#                 Volume       sma200        rsi  signal
# Date
# 1996-01-02   364180000          NaN        NaN   False
# 1996-01-03   468950000          NaN        NaN   False
# 1996-01-04   512580000          NaN        NaN   False
# 1996-01-05   437110000          NaN        NaN   False
# 1996-01-08   130360000          NaN        NaN   False
# ...                ...          ...        ...     ...
# 2024-07-29  3379970000  4986.034155  43.636131   False
# 2024-07-30  3777740000  4991.331604  40.506981   False
# 2024-07-31  4546910000  4997.195054  52.498281   False
# 2024-08-01  4703620000  5002.789556  43.849303   False
# 2024-08-02  5156450000  5007.654207  35.295118   False
#
# [7196 rows x 9 columns]

# %%
Buying_dates, Selling_dates = [],[]



for i in range(len(df)-1):
    if df.signal.iloc[i]:
        Buying_dates.append(df.iloc[i+1].name)
        for j in range(1,11):
            if df.rsi.iloc[i + j] > 40:
                Selling_dates.append(df.iloc[i + j + 1].name)
                break
            elif j == 10:
                Selling_dates.append(df.iloc[i + j + 1].name)

# %%
Buying_dates = np.where(df.signal, df.index, np.nan)
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 Buying_dates = np.where(df.signal, df.index, np.nan)
#
# DTypePromotionError: The DType <class 'numpy.dtypes.DateTime64DType'> could not be promoted by <class 'numpy.dtypes.Float64DType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.DateTime64DType'>, <class 'numpy.dtypes.Float64DType'>)

# %%
frame = pd.DataFrame({'Buying_dates':Buying_dates, 'Selling_dates':Selling_dates})
frame
# Out:
#    Buying_dates Selling_dates
# 0    1996-12-17    1996-12-19
# 1    1997-04-01    1997-04-09
# 2    1997-04-02    1997-04-09
# 3    1997-04-03    1997-04-09
# 4    1997-04-04    1997-04-09
# ..          ...           ...
# 85   2023-09-28    2023-10-09
# 86   2023-10-04    2023-10-09
# 87   2024-04-18    2024-04-24
# 88   2024-04-19    2024-04-24
# 89   2024-04-22    2024-04-24
#
# [90 rows x 2 columns]
